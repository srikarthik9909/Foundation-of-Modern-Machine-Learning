# %% [markdown]
# <a href="https://colab.research.google.com/github/srikarthik9909/Foundation-of-Modern-Machine-Learning/blob/main/Module_8_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 09:42:01--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   196MB/s    in 0.4s
#
# 2023-05-03 09:42:02 (196 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1953    1210.7053v2  Inference is an integral part of probabilistic...  stat
# 6697   1705.06452v1  Adversarial examples have been shown to exist ...  stat
# 37512  1708.09020v1  As a firm varies the price of a product, consu...    cs
# 21812   0808.0780v1  The local linear embedding algorithm (LLE) is ...  stat
# 650    1709.06671v1  Distributed word embeddings have shown superio...    cs
# ...             ...                                                ...   ...
# 27959  1705.01842v2  Facial expressions play a significant role in ...    cs
# 26839  1611.10195v3  Fast and accurate upper-body and head pose est...    cs
# 5951    1305.7454v1  Many machine learning algorithms assume that a...    cs
# 37668  1712.07770v1  Approximate model counting for bit-vector SMT ...    cs
# 6963   1708.02666v1  This is the Proceedings of the 2017 ICML Works...  stat
#
#                                                    title  year  \
# 1953   Managing sparsity, time, and quality of infere...  2012
# 6697   Delving into adversarial attacks on deep policies  2017
# 37512           Learning to Price with Reference Effects  2017
# 21812  LLE with low-dimensional neighborhood represen...  2008
# 650    Think Globally, Embed Locally --- Locally Line...  2017
# ...                                                  ...   ...
# 27959  A Deep Learning Perspective on the Origin of F...  2017
# 26839  POSEidon: Face-from-Depth for Driver Pose Esti...  2016
# 5951          Privileged Information for Data Clustering  2013
# 37668  Bit-Vector Model Counting using Statistical Es...  2017
# 6963   Proceedings of the 2017 ICML Workshop on Human...  2017
#
#                                                 keywords
# 1953   [inference, probabilistic, efficient, algorith...
# 6697   [adversarial, architectures, reinforcement, pr...
# 37512  [consumers, reference, decisions, prevailing, ...
# 21812  [embedding, algorithm, dimension, technique, c...
# 650    [distributed, embeddings, performances, proces...
# ...                                                  ...
# 27959  [expressions, significant, communication, psyc...
# 26839  [estimation, automatic, monitoring, attention,...
# 5951   [algorithms, independently, identically, distr...
# 37668  [approximate, applications, probabilistic, inf...
# 6963   [proceedings, interpretability, australia, pro...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1953     [inference, probabilistic, efficient, algorith...
# 6697     [adversarial, architectures, reinforcement, pr...
# 37512    [consumers, reference, decisions, prevailing, ...
# 21812    [embedding, algorithm, dimension, technique, c...
# 650      [distributed, embeddings, performances, proces...
#                                ...
# 208      [recognition, augmenting, classifier, auxiliar...
# 3274     [surrogate, functions, nonconvex, functions, n...
# 6752     [approximate, properties, approximates, distan...
# 21670    [restaurant, stochastic, probability, distribu...
# 30029    [algorithm, diagnosis, mammograms, annotations...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8731 words.
# Out of those 4527 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fb2fef80-e3b7-4bf9-82a4-5a856a3de5f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb2fef80-e3b7-4bf9-82a4-5a856a3de5f4")) {                    Plotly.newPlot(                        "fb2fef80-e3b7-4bf9-82a4-5a856a3de5f4",                        [{"x":["flexibility","framework","algorithm","challenging","representations","demonstrate","knowledge","documents","introduce","nonconjugate","inference","probabilistic","efficiently","convergence","incorporate","efficient","architectures","reinforcement","resilience","successful","adversarial","perturbations","effectiveness","promising","performance","tractable","dependence","considerable","intelligently","systematic","reference","informative","attribution","consumers","generated","sequences","maximizing","behavioral","exploration","effective","particular","information","prevailing","decisions","establish","complexity","consequences","simulations","guarantees","illustrate","perturbation","embedding","theoretically","regularization","dimensional","computational","neighbors","technique","numerical","preserves","neighborhood","neighborhoods","sensitivity","structure","demonstrating","modification","intuitive","representation","reconstructs","computationally","relations","projection","dimension","reconstruction","sensitive","straightforward","consequently","simplicity","individual","neighbourhoods","establishing","experimental","processing","outperform","similarity","different","complementary","concatenation","performances","unsupervised","integrating","previously","important","therefore","competitive","benchmark","classification","semantics","distributed","embeddings","significantly","differences","vocabulary","mentioned","assessment","reasoning","additional","approximately","production","utilizing","organizing","remarkable","influence","parameters","recognition","essential","attribute","extracted","thickness","approximate","variables","collected","advancing","inapplicable","graphical","experiments","uncertainty","converting","importance","component","algorithms","progresses","motivates","supervised","combining","conducted","available","processed","assumption","underlying","outperforms","probability","prediction","techniques","estimating","typically","selecting","accomplished","recording","especially","estimates","mechanism","estimation","egocentric","probabilities","transformations","transformation","separation","dimensionality","predecessor","substantially","proposals","engineered","generation","effectively","approaches","principal","detection","engineering","microsoft","increases","improving","fundamental","multiscale","challenge","combinatorial","convolutional","generalization","difficult","directions","paradigms","situation","representative","including","advantages","theoretical","clustering","characteristics","applications","categories","contained","projecting","pretrained","multilayer","limitation","optimized","alternative","extensively","classifier","architecture"],"y":[32,569,803,282,223,610,393,69,347,0,206,171,156,106,61,423,117,120,9,74,98,22,219,120,880,36,27,44,9,34,58,43,7,6,180,84,28,18,75,281,284,714,4,61,59,229,14,53,65,87,9,94,36,89,196,281,19,271,89,15,32,8,42,323,29,28,36,339,5,86,89,48,68,85,70,19,26,22,121,3,21,383,285,85,154,734,42,4,39,137,38,93,348,130,111,206,516,113,108,80,277,49,23,22,37,124,117,32,26,37,11,30,69,245,381,64,39,105,3,134,139,89,8,2,53,611,86,7,94,101,607,4,11,212,118,72,303,31,75,108,266,182,216,383,60,100,39,6,11,124,74,121,210,12,64,38,58,29,56,3,34,23,11,138,108,413,36,345,57,8,50,104,86,12,143,40,403,127,136,45,17,32,31,254,70,177,164,81,441,63,17,10,12,20,23,56,92,46,154,236],"type":"bar"},{"x":["flexibility","framework","algorithm","challengi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4527,), (4527, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>Task</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7119341563786008);'>Segmentation</span> <span style=''>of</span> <span style=''>Building</span> <span style=''>Footprints</span> <span style=''>with</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.30303030303030304);'>increased</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>availability</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.5890410958904111);'>resolution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satellite</span> <span style=''>imagery</span> <span style=''>allows</span> <span style=''>to</span> <span style=''>sense</span> <span style=''>very</span> <span style=''>detailed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>on</span> <span style=''>the</span> <span style=''>surface</span> <span style=''>of</span> <span style=''>our</span> <span style=''>planet</span> <span style=''>Access</span> <span style=''>to</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>opens</span> <span style=''>up</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directions</span> <span style=''>in</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>remote</span> <span style=''>sensing</span> <span style=''>imagery</span> <span style=''>However</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>this</span> <span style=''>raises</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3411764705882353);'>challenges</span> <span style=''>for</span> <span style=''>existing</span> <span style=''>pixel</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.7119341563786008);'>segmentation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>While</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>achieved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>the</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.7119341563786008);'>segmentation</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.5890410958904111);'>resolution</span> <span style=''>images</span> <span style=''>in</span> <span style=''>the</span> <span style=''>past</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>produce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>with</span> <span style=''>poor</span> <span style='background-color:rgba(0, 255, 0, 0.5813953488372094);'>boundaries</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Aggregation</span> <span style=''>using</span> <span style=''>input</span> <span style=''>output</span> <span style=''>trade</span> <span style=''>off</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>learning</span> <span style=''>strategy</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>seminal</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>Mojirsheibani</span> <span style=''>(1999</span> <span style=''>2000</span> <span style=''>2002a</span> <span style=''>2002b)</span> <span style=''>who</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>smart</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>relying</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style=''>notion</span> <span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregation</span> <span style=''>methods</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>for</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>x</span> <span style=''>is</span> <span style=''>computed</span> <span style=''>by</span> <span style=''>building</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>or</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>over</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>basic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>r1(x)</span> <span style=''>rm(x)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibrated</span> <span style=''>using</span> <span style=''>a</span> <span style=''>training</span> <span style=''>data</span> <span style=''>set</span> <span style=''>Mojirsheibani</span> <span style=''>proposes</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>to</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style=''>selected</span> <span style=''>outputs</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>examples</span> <span style=''>The</span> <span style=''>output</span> <span style=''>of</span> <span style=''>a</span> <span style=''>training</span> <span style=''>example</span> <span style=''>is</span> <span style=''>selected</span> <span style=''>if</span> <span style=''>some</span> <span style=''>kind</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style=''>is</span> <span style=''>observed</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>computed</span> <span style=''>for</span> <span style=''>the</span> <span style=''>training</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Loss</span> <span style='background-color:rgba(255, 0, 0, 0.3571428571428572);'>Proportional</span> <span style='background-color:rgba(255, 0, 0, 0.7);'>Subsampling</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Subsequent</span> <span style=''>ERM</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>sampling</span> <span style=''>scheme</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>reducing</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>prior</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>with</span> <span style=''>minimum</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style=''>The</span> <span style=''>sampling</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ultimate</span> <span style=''>(unknown)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>set</span> <span style=''>but</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonetheless</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>that</span> <span style=''>the</span> <span style=''>final</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>will</span> <span style=''>compare</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>favorably</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>utilizing</span> <span style=''>the</span> <span style=''>entire</span> <span style=''>original</span> <span style=''>data</span> <span style=''>set</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>benefits</span> <span style=''>of</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>on</span> <span style=''>a</span> <span style=''>large</span> <span style=''>dataset</span> <span style=''>which</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>subsample</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subsequently</span> <span style=''>fit</span> <span style=''>with</span> <span style=''>boosted</span> <span style=''>trees</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Hashing</span> <span style=''>as</span> <span style=''>Tie</span> <span style=''>Aware</span> <span style=''>Learning</span> <span style=''>to</span> <span style=''>Rank</span> <br/><br/><span style=''>Hashing</span> <span style=''>or</span> <span style=''>learning</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>of</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequently</span> <span style=''>used</span> <span style=''>in</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieval</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulations</span> <span style=''>for</span> <span style=''>hashing</span> <span style=''>aimed</span> <span style=''>at</span> <span style=''>directly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>ranking</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>metrics</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Average</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Precision</span> <span style=''>(AP)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Normalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discounted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Cumulative</span> <span style=''>Gain</span> <span style=''>(NDCG)</span> <span style=''>We</span> <span style=''>first</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>the</span> <span style=''>integer</span> <span style=''>valued</span> <span style=''>Hamming</span> <span style=''>distance</span> <span style=''>often</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>tied</span> <span style=''>rankings</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>tie</span> <span style=''>aware</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>AP</span> <span style=''>and</span> <span style=''>NDCG</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>hashing</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieval</span> <span style=''>Then</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>tie</span> <span style=''>aware</span> <span style=''>ranking</span> <span style=''>metrics</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxations</span> <span style=''>and</span> <span style=''>perform</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>with</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Our</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>the</span> <span style=''>new</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieval</span> <span style=''>by</span> <span style=''>Hamming</span> <span style=''>ranking</span> <span style=''>in</span> <span style=''>common</span> <spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08431582708110039)
# 	experimental (0.1368345837799214)
# 	processing (0.10182207931404073)
# 	segmentation (0.07431225437656305)
# 	information (0.25509110396570206)
# 	knowledge (0.14040728831725616)
# 	detection (0.1232583065380493)
# 	different (0.26223651304037154)
# 	recognition (0.13612004287245444)
# 	convolutional (0.14397999285459093)
#
# Some Statistics words are:
# 	convergence (0.12243878060969515)
# 	variables (0.14042978510744628)
# 	stochastic (0.14342828585707146)
# 	estimation (0.17041479260369816)
# 	statistical (0.15342328835582209)
# 	algorithm (0.3893053473263368)
# 	distribution (0.19140429785107446)
# 	dimensional (0.1874062968515742)
# 	inference (0.20439780109945027)
# 	regression (0.18440779610194902)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="23bdb160-ac37-40d9-bdb7-475a8474ea2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23bdb160-ac37-40d9-bdb7-475a8474ea2d")) {                    Plotly.newPlot(                        "23bdb160-ac37-40d9-bdb7-475a8474ea2d",                        [{"x":["flexibility","framework","algorithm","challenging","representations","demonstrate","knowledge","documents","introduce","nonconjugate","inference","probabilistic","efficiently","convergence","incorporate","efficient","architectures","reinforcement","resilience","successful","adversarial","perturbations","effectiveness","promising","performance","tractable","dependence","considerable","intelligently","systematic","reference","informative","attribution","consumers","generated","sequences","maximizing","behavioral","exploration","effective","particular","information","prevailing","decisions","establish","complexity","consequences","simulations","guarantees","illustrate","perturbation","embedding","theoretically","regularization","dimensional","computational","neighbors","technique","numerical","preserves","neighborhood","neighborhoods","sensitivity","structure","demonstrating","modification","intuitive","representation","reconstructs","computationally","relations","projection","dimension","reconstruction","sensitive","straightforward","consequently","simplicity","individual","neighbourhoods","establishing","experimental","processing","outperform","similarity","different","complementary","concatenation","performances","unsupervised","integrating","previously","important","therefore","competitive","benchmark","classification","semantics","distributed","embeddings","significantly","differences","vocabulary","mentioned","assessment","reasoning","additional","approximately","production","utilizing","organizing","remarkable","influence","parameters","recognition","essential","attribute","extracted","thickness","approximate","variables","collected","advancing","inapplicable","graphical","experiments","uncertainty","converting","importance","component","algorithms","progresses","motivates","supervised","combining","conducted","available","processed","assumption","underlying","outperforms","probability","prediction","techniques","estimating","typically","selecting","accomplished","recording","especially","estimates","mechanism","estimation","egocentric","probabilities","transformations","transformation","separation","dimensionality","predecessor","substantially","proposals","engineered","generation","effectively","approaches","principal","detection","engineering","microsoft","increases","improving","fundamental","multiscale","challenge","combinatorial","convolutional","generalization","difficult","directions","paradigms","situation","representative","including","advantages","theoretical","clustering","characteristics","applications","categories","contained","projecting","pretrained","multilayer","limitation","optimized","alternative","extensively","classifier","architecture","leverages","discriminative","transferring","resorting","realistic","imbalance","balancing","stability","explanation","gradually","automatically","generator","revealing","instabilities","distribution","necessary","generative","discriminator","considered","distributions","finetuning","improvements","generalizability","simultaneously","individually","comparable","generalizes","accuracies","redundancy","equivalent","propositional","attention","construct","recommendations","according","constructing","hierarchical","personalized","conceptual","corresponding","organized","attentions","interests","ontologies","perspective","constructed","encapsulated","hierarchy","aggregated","capability","significant","linguistic","dependency","se ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonconjugate
# 	disaggregation
# 	preferably
# 	interventional
# 	misspecified
# 	stragglers
# 	replication
# 	straggler
# 	straggling
# 	predecessors
# 	inspecting
# 	spectroradiometer
# 	thetastar
# 	compressible
# 	contrasting
# 	nomination
# 	percentile
# 	prospective
# 	eigendecomposition
# 	landscapes
# Some words which never appear in Statistics papers:
# 	prevailing
# 	neighbourhoods
# 	concatenation
# 	thickness
# 	predecessor
# 	pretrained
# 	finetuning
# 	propositional
# 	ontologies
# 	categorial
# 	roughness
# 	tomographic
# 	delineation
# 	taxonomies
# 	gathering
# 	operative
# 	institute
# 	lifestyle
# 	insufficiency
# 	panoramas

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075314450902605e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7766666666666666
